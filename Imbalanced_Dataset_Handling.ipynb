# %% [markdown]
# <a href="https://colab.research.google.com/github/TanyaKumari0204/Machine-Learning/blob/main/Imbalanced_Dataset_Handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imbalanced dataset:-
# unequal clkass distribution mnn lo 2 value hai yes no,yes nht jda aur no bht kmm to yhi imbalanced dataset hai

# %%
import pandas as pd
import numpy as np

# %%
credit_card_data=pd.read_csv('/content/credit_data.csv.crdownload')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 19893  30631 -0.377215  0.973528  1.647077  0.732439  0.024728 -0.541379
# 19894  30631  1.209281  0.078793  0.061820  0.593730 -0.235772 -0.448524
# 19895  30632  1.286596 -1.450336  0.814530 -1.308949 -2.055209 -0.592064
# 19896  30633 -0.488090  1.018448  0.670593 -0.245462  0.828347 -0.233102
# 19897  30633 -2.609841  2.479357  0.763844  0.044509 -0.645716  0.762867
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 19893  0.828488 -0.060740 -0.725148  ...  0.228443  0.685913 -0.107687
# 19894 -0.141196  0.089236  0.411825  ... -0.302369 -0.984051  0.130401
# 19895 -1.317286  0.032386 -1.720017  ...  0.040743  0.262534 -0.045112
# 19896  0.662586 -0.040028 -0.279439  ... -0.344859 -0.902035 -0.050171
# 19897 -1.626415 -7.617854  1.399746  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data['Class'].value_counts()#We see highly imbalnced dataset
# Out:
# Class
# 0.0    19812
# 1.0       85
# Name: count, dtype: int64

# %% [markdown]
# 0->Legit transaction
# 1->Fraudelent Transaction

# %%
legit=credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)#bht jda
print(fraud.shape)#bht kmm
# Out:
# (19812, 31)
# (85, 31)

# %% [markdown]
# UNDERSAMPLING

# %%
#jo kmmm h,utna hi jada vla lo

# %% [markdown]
# Building a sample dataset containing similar distribution of Legit and Fraud

# %%
#similar lenge
legit_sample=legit.sample(82)#kyuki fraud 82 hai

# %%
legit_sample.shape
# Out:
# (82, 31)

# %%
#concat legit_sample and fraud

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)#concat row wise

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 8219   11054  1.261183 -0.118257  0.535363  0.023434 -0.432218 -0.058873
# 3826    3345 -1.117517  0.581767  2.619357  0.022409 -0.459888  0.087052
# 15610  27013 -0.431994  0.716932  1.118830  0.869642  0.655867  0.018484
# 19310  30173 -2.316317  1.454811  0.991197 -0.120972 -0.036084 -1.405087
# 18954  29904  1.176611  0.654971  0.787855  2.474583 -0.157825 -0.519726
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 8219  -0.600160  0.032861  1.631439  ... -0.076506 -0.022961 -0.122519
# 3826   0.383053  0.083236 -0.013164  ...  0.307052  0.828164 -0.336018
# 15610  1.242807 -0.212268 -0.652560  ... -0.408023 -1.095645  0.316846
# 19310  1.010460 -0.156352  0.313074  ... -0.294180 -0.103222  0.041075
# 18954  0.180639 -0.143971 -0.847342  ... -0.238051 -0.739041  0.131482
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time         V1         V2         V3        V4         V5        V6  \
# 17480  28755 -30.552380  16.713389 -31.103685  6.534984 -22.105532 -4.977692
# 18466  29526   1.102804   2.829168  -3.932870  4.707691   2.937967 -1.800904
# 18472  29531  -1.060676   2.608579  -2.971679  4.360089   3.738853 -2.728395
# 18773  29753   0.269614   3.549755  -5.810353  5.809370   1.538808 -2.269219
# 18809  29785   0.923764   0.344048  -2.880004  1.721680  -3.019565 -0.639736
#
#               V7         V8        V9  ...       V21       V22       V23  \
# 17480 -20.371514  20.007208 -3.565738  ...  1.816520 -2.288686 -1.460544
# 18466   1.672734  -0.300240 -2.783011  ... -0.106994 -0.250050 -0.521627
# 18472   1.987616  -0.357345 -2.757535  ... -0.063168 -0.207385 -0.183261
# 18773  -0.824203   0.351070 -3.759059  ...  0.371121 -0.322290 -0.549856
# 18809  -3.801325   1.299096  0.864065  ...  0.899931  1.481271  0.725266
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 1.0    85
# 0.0    82
# Name: count, dtype: int64
